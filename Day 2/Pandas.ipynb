# %% [markdown]
# Introduction to Pandas
# ==================
#
# This notebook is heavily inspired from: [10 minutes to Pandas, an tutorial by the official developers](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Difference between numpy array and pandas Series

# %%
a = np.array([1,3, 5, np.nan, 6, 8])
a

# %%
# one very useful and handy feature of jupyter/colab notebooks is tab completion. 

s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s

# %% [markdown]
# #### Creating a DataFrame

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})

# %%
df2

# %%
# !wget https://gist.github.com/tdchaitanya/d84c787328df169c50a06eb1669666c9/raw/7ffeddc80bec1c22e91bfed6e026620cf989eacf/housing_data.csv

# %%
df = pd.read_csv('housing_data.csv')

# %%
df.head(5)

# %%
df.tail(5)

# %%
df.describe()

# %%
df.sort_values(by='price').head()

# %% [markdown]
# #### Playing with the data

# %%
df["id"].head()

# %%
df[["id", "date", "price"]].head()

# %%
df[df['price'] > 10000].head()

# %%
# you can chain the operations
df[df['price'] > 10000].sort_values(by='price', ascending=False).head()

# %%
import datetime as dt
df['date'].apply(pd.to_datetime).head()

# %% [markdown]
# Some commonly used functions:
#
# *  [loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html)
# *  [concat](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html),  [merge](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) and [join](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)
